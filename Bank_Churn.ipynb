# %% [markdown]
# # **I. EDA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/sample_data/BankChurners.csv')

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df.tail()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
df.shape
# Out:
# (10133, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
df.describe(include = 'object')
# Out:
#            Attrition_Flag Gender Education_Level Marital_Status  \
# count               10127  10127           10127          10127
# unique                  2      2               7              4
# top     Existing Customer      F        Graduate        Married
# freq                 8500   5358            3128           4687
#
#        Income_Category Card_Category
# count            10127         10127
# unique               6             4
# top     Less than $40K          Blue
# freq              3561          9436

# %%
for i in df.select_dtypes(include = 'object').columns:
  print(df[i].value_counts())
  print("***"*10)
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64
# ******************************
# Gender
# F    5358
# M    4769
# Name: count, dtype: int64
# ******************************
# Education_Level
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: count, dtype: int64
# ******************************
# Marital_Status
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: count, dtype: int64
# ******************************
# Income_Category
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: count, dtype: int64
# ******************************
# Card_Category
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: count, dtype: int64
# ...

# %%
object_columns = df.select_dtypes(include='object').columns
for col in object_columns:
  df[col].value_counts().plot(kind='bar')
  plt.title(col)
  plt.show()

# %%
df.describe().T
# Out:
#                                                       count          mean  \
# CLIENTNUM                                           10127.0  7.391776e+08
# Customer_Age                                        10127.0  4.632596e+01
# Dependent_count                                     10127.0  2.346203e+00
# Months_on_book                                      10127.0  3.592841e+01
# Total_Relationship_Count                            10127.0  3.812580e+00
# Months_Inactive_12_mon                              10127.0  2.341167e+00
# Contacts_Count_12_mon                               10127.0  2.455317e+00
# Credit_Limit                                        10127.0  8.631954e+03
# Total_Revolving_Bal                                 10127.0  1.162814e+03
# Avg_Open_To_Buy                                     10127.0  7.469140e+03
# Total_Amt_Chng_Q4_Q1                                10127.0  7.599407e-01
# Total_Trans_Amt                                     10127.0  4.404086e+03
# ...

# %% [markdown]
# - Độ tuổi trung bình là khoảng 46 tuổi. Một nửa số khách hàng từ 41 đến 52 tuổi, cho thấy hồ sơ lớn tuổi hơn.
# - Trung bình, khách hàng nắm giữ khoảng 4 sản phẩm của ngân hàng.
# - 75% khách hàng đã dành ít nhất 2 tháng không hoạt động trong 12 tháng qua. Đây là một chỉ số không tốt. Ngân hàng phải lập kế hoạch chiến lược để cải thiện mức tiêu thụ của khách hàng.
# - 75% khách hàng đã liên hệ với ngân hàng ít nhất 2 lần trong 12 tháng qua. Điều này cũng không tốt, có điều gì đó trong sản phẩm thẻ tín dụng khiến khách hàng liên hệ với công ty, có thể là không hài lòng.
# - Hạn mức tín dụng trung bình là 8.632. Hơn nữa, có vẻ như nó bị lệch sang phải (trung bình lớn hơn trung vị, hạn mức tín dụng tối thiểu là 1.438, trong khi tối đa là 34.516).
# - Tỷ lệ sử dụng trung bình là khoảng 28%. Đây là một giá trị thấp. Hơn nữa, một nửa số khách hàng có tỷ lệ sử dụng lên tới 17,6%. Ngân hàng phải chú ý đến điều này và cố gắng tăng cường sử dụng dịch vụ thẻ tín dụng của mình.
# - Trung bình, khách hàng đã thực hiện khoảng 65 giao dịch trong 12 tháng qua. Điều này cho thấy khách hàng đã thực hiện khoảng 5,4 giao dịch mỗi tháng trong một năm, rất thấp.
# - Hơn nữa, khi quan sát các giá trị tối thiểu và tối đa, có vẻ như không có giá trị nào không nhất quán.

# %%
numerical_columns = df.select_dtypes(include='number').columns

n_cols = 4
n_rows = -(-len(numerical_columns) // n_cols)

plt.figure(figsize=(10, 10))

for idx, column in enumerate(numerical_columns):
    plt.subplot(n_rows, n_cols, idx + 1)
    sns.histplot(df[column], kde=True)
    plt.title(column)
    plt.tight_layout()

plt.show()

# %% [markdown]
# - Hầu hết khách hàng đều trong độ tuổi từ 40 đến 50.
# - Một bộ phận lớn khách hàng đã dành 36 tháng để sử dụng dịch vụ thẻ tín dụng của ngân hàng.
# - Hạn mức tín dụng bị lệch phải. Điều này có nghĩa là phần lớn khách hàng có hạn mức tín dụng thấp, trong khi có tương đối ít khách hàng có hạn mức tín dụng cao. Tuy nhiên, có thể thấy rằng một bộ phận đáng kể trong số họ, khoảng 5%, có hạn mức tín dụng cao, khoảng 35.000. Hơn nữa, cả avg_open_to_buy và avg_utilization_ratio cũng bị lệch dương.
# - Ngân hàng phải cảnh giác với sự phân phối của tỷ lệ sử dụng trung bình. Bị lệch phải có nghĩa là hầu hết khách hàng có tỷ lệ sử dụng dịch vụ thấp. Đặc biệt, một bộ phận lớn trong số họ, khoảng 25%, có tỷ lệ sử dụng bằng không. Do đó, công ty phải lập kế hoạch chiến lược để tăng tỷ lệ sử dụng và do đó là tăng doanh thu.
# - Một bộ phận lớn khách hàng, cũng khoảng 25%, có tổng số dư luân chuyển bằng không. Tổng số dư luân chuyển thấp hơn (đặc biệt là số không) có thể chỉ ra khả năng xảy ra tình trạng churn đáng kể. Xem xét tỷ lệ sử dụng trung bình và tổng số dư luân chuyển có cùng tỷ lệ bản ghi bằng không, các biến này có thể có mối tương quan. Tôi sẽ điều tra thêm về điều này trong phần phân tích.
# - Tổng số giao dịch và phân phối số tiền dường như có hai đỉnh. Phải có sự khác biệt trong các phân phối này đối với cờ churn, mà tôi sẽ điều tra thêm trong phần phân tích. Hơn nữa, một phần lớn khách hàng đã thực hiện khoảng 80 hoặc 40 giao dịch trong 12 tháng qua. Số lượng giao dịch khoảng 5.000 và 2.500 là phổ biến.
# - Khoảng 80% khách hàng nắm giữ ít nhất 3 sản phẩm của ngân hàng.

# %% [markdown]
# # **II. Data Processing**

# %%
#xóa 2 cột cuối
df.drop(df.columns[len(df.columns) - 2], axis = 1, inplace = True)
df.drop(df.columns[len(df.columns) - 1], axis = 1, inplace = True)

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# CLIENTNUM                   0.000000
# Attrition_Flag              0.000000
# Customer_Age                0.000000
# Gender                      0.000000
# Dependent_count             0.009869
# Education_Level             0.009869
# Marital_Status              0.000000
# Income_Category             0.000000
# Card_Category               0.000000
# Months_on_book              0.000000
# Total_Relationship_Count    0.000000
# Months_Inactive_12_mon      0.000000
# Contacts_Count_12_mon       0.000000
# Credit_Limit                0.000000
# Total_Revolving_Bal         0.000000
# Avg_Open_To_Buy             0.009869
# Total_Amt_Chng_Q4_Q1        0.000000
# Total_Trans_Amt             0.000000
# Total_Trans_Ct              0.000000
# Total_Ct_Chng_Q4_Q1         0.000000
# Avg_Utilization_Ratio       0.000000
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(inplace = True)

# %%
numerical_columns = df.select_dtypes(include='number').columns

n_cols = 4
n_rows = -(-len(numerical_columns) // n_cols)

plt.figure(figsize=(10, 10))

for idx, column in enumerate(numerical_columns):
    plt.subplot(n_rows, n_cols, idx + 1)
    sns.boxplot(df[column])
    plt.title(column)
    plt.tight_layout()

plt.show()

# %% [markdown]
# Tỷ lệ oulier thấp trong mỗi biến. Hơn nữa chúng không biểu thị thông tin không nhất quán như lỗi đo lường, nên sẽ không xử lý oulier.

# %% [markdown]
# Xử lý outlier ở 2 biến liên tục có rất nhiều oulier là Total_Amt_Chng_Q4_Q1, Total_Ct_Chng_Q4_Q1

# %%
p25 = df['Total_Amt_Chng_Q4_Q1'].quantile(0.25)
p75 = df['Total_Amt_Chng_Q4_Q1'].quantile(0.75)
iqr = p75 - p25

lower_bound = p25 - 1.5 * iqr
upper_bound = p75 + 1.5 * iqr

df = df[(df['Total_Amt_Chng_Q4_Q1'] >= lower_bound) & (df['Total_Amt_Chng_Q4_Q1'] <= upper_bound)]
df = df[(df['Total_Ct_Chng_Q4_Q1'] >= lower_bound) & (df['Total_Ct_Chng_Q4_Q1'] <= upper_bound)]

# %%
# xóa unknown khỏi các cọt education, marital, income
df = df[df['Education_Level'] != 'Unknown']
df = df[df['Marital_Status'] != 'Unknown']
df = df[df['Income_Category'] != 'Unknown']

# %%
df.to_csv('bank_churn_cleaned.csv', index=False)

# %%
df.select_dtypes(include = 'number').columns
# Out:
# Index(['CLIENTNUM', 'Customer_Age', 'Dependent_count', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
for i in ['CLIENTNUM', 'Customer_Age', 'Dependent_count', 'Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']:
       sns.scatterplot(data=df, x=i, y='Attrition_Flag')
       plt.show()

# %% [markdown]
# Cột id không có ý nghĩa phân tích nên sẽ bị xóa

# %%
df = df.drop('CLIENTNUM', axis=1)

# %%
df['Gender'] = df['Gender'].map({'M': 1, 'F': 0})
df['Attrition_Flag'] = df['Attrition_Flag'].map({'Attrited Customer': 1, 'Existing Customer': 0})

# %%
df_dummy = pd.get_dummies(df, drop_first=True)

# %%
df_dummy
# Out:
#        Attrition_Flag  Customer_Age  Gender  Dependent_count  Months_on_book  \
# 0                   0            45       1                3              39
# 1                   0            49       0                5              44
# 2                   0            51       1                3              36
# 4                   0            40       1                3              21
# 5                   0            44       1                2              36
# ...               ...           ...     ...              ...             ...
# 10120               0            54       1                1              34
# 10121               0            56       0                1              50
# 10122               0            50       1                2              40
# 10124               1            44       0                1              36
# 10126               1            43       0                2              25
#
# ...

# %%
df.Attrition_Flag.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Attrition_Flag'>

# %% [markdown]
# => dữ liệu bị mất cân bằng

# %%
corr = df_dummy.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_839c1_row0_col0, #T_839c1_row1_col1, #T_839c1_row2_col2, #T_839c1_row3_col3, #T_839c1_row4_col4, #T_839c1_row5_col5, #T_839c1_row6_col6, #T_839c1_row7_col7, #T_839c1_row8_col8, #T_839c1_row8_col10, #T_839c1_row9_col9, #T_839c1_row10_col8, #T_839c1_row10_col10, #T_839c1_row11_col11, #T_839c1_row12_col12, #T_839c1_row13_col13, #T_839c1_row14_col14, #T_839c1_row15_col15, #T_839c1_row16_col16, #T_839c1_row17_col17, #T_839c1_row18_col18, #T_839c1_row19_col19, #T_839c1_row20_col20, #T_839c1_row21_col21, #T_839c1_row22_col22, #T_839c1_row23_col23, #T_839c1_row24_col24, #T_839c1_row25_col25, #T_839c1_row26_col26, #T_839c1_row27_col27, #T_839c1_row28_col28, #T_839c1_row29_col29 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...

# %%
import numpy as np

threshold = 0.8

high_corr_cols = set()
for i in range(len(corr.columns)):
    for j in range(i):
        if abs(corr.iloc[i, j]) > threshold:
            colname = corr.columns[i]
            high_corr_cols.add(colname)

high_corr_cols = list(high_corr_cols)
print(high_corr_cols)
# Out:
# ['Total_Trans_Ct', 'Marital_Status_Single', 'Avg_Open_To_Buy']

# %%
df_dummy['Avg_Trans_Amt'] = df_dummy['Total_Trans_Amt'] / df_dummy['Total_Trans_Ct']
df_dummy = df_dummy.drop(['Total_Trans_Ct', 'Total_Trans_Amt'], axis=1)

# %%
df_dummy = df_dummy.drop(columns=high_corr_cols)

# %% [markdown]
# # **III. Xây dựng model**

# %%
#các thư viện nomarlize data
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
#các thư viện xử lý imbalance
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# %%
#import các thư viện để phát triển model dự đoán
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# %%
#import các model
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# **ex1 smote + minmax + log**

# %%
x = df_dummy.drop('Attrition_Flag', axis=1)
y = df_dummy['Attrition_Flag']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

sm = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = sm.fit_resample(X_train, y_train)

scale_columns = ['Customer_Age', 'Dependent_count', 'Months_on_book', 'Total_Relationship_Count',
                 'Months_Inactive_12_mon', 'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
                 'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1',
                 'Avg_Utilization_Ratio']

scaler = MinMaxScaler()
X_train_resampled[scale_columns] = scaler.fit_transform(X_train_resampled[scale_columns])
X_test[scale_columns] = scaler.transform(X_test[scale_columns])

# %%
model_log = LogisticRegression()
model_log.fit(X_train_resampled, y_train_resampled)
y_pred = model_log.predict(X_test)

print(classification_report(y_test, y_pred))

ConfusionMatrixDisplay.from_estimator(model_log, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93      1205
#            1       0.59      0.67      0.63       212
#
#     accuracy                           0.88      1417
#    macro avg       0.76      0.79      0.78      1417
# weighted avg       0.89      0.88      0.88      1417

# %% [markdown]
# **ex2 xgboost**

# %%
x = df_dummy.drop('Attrition_Flag', axis=1)
y = df_dummy['Attrition_Flag']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from ast import mod
import xgboost as xgb

model_xgb = xgb.XGBClassifier(learning_rate=0.1, n_estimators=300, max_depth=5)
model_xgb.fit(x_train, y_train)

y_pred = model_xgb.predict(x_test)

print(classification_report(y_test, y_pred))

ConfusionMatrixDisplay.from_estimator(model_xgb, x_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1205
#            1       0.94      0.86      0.90       212
#
#     accuracy                           0.97      1417
#    macro avg       0.96      0.93      0.94      1417
# weighted avg       0.97      0.97      0.97      1417

# %% [markdown]
# Ex3 random forest

# %%
x = df_dummy.drop('Attrition_Flag', axis=1)
y = df_dummy['Attrition_Flag']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model_rf = RandomForestClassifier()
model_rf.fit(x_train, y_train)

y_pred = model_rf.predict(x_test)

print(classification_report(y_test, y_pred))

ConfusionMatrixDisplay.from_estimator(model_xgb, x_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      1205
#            1       0.93      0.77      0.84       212
#
#     accuracy                           0.96      1417
#    macro avg       0.94      0.88      0.91      1417
# weighted avg       0.96      0.96      0.96      1417

# %%
#tìm tham số tối ưu cho xgboost
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
# Định nghĩa lưới các giá trị hyperparameter
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200, 300]
}

# Khởi tạo mô hình XGBoost
xgb = XGBClassifier()

# Tìm kiếm hyperparameter tối ưu với GridSearchCV
grid_search = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=5, scoring='recall')
grid_search.fit(x_train, y_train)

# In kết quả
print("Best parameters found: ", grid_search.best_params_)
print("Best score found: ", grid_search.best_score_)
# Out:
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300}
# Best score found:  0.880184162062615

# %%
#kiểm tra mô hình có bị overfitting
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

x = df_dummy.drop('Attrition_Flag', axis=1)
y = df_dummy['Attrition_Flag']

# Tạo tập train, validation và test
X_train_val, X_test, y_train_val, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42)

# Huấn luyện mô hình XGBoost
xgb = XGBClassifier(learning_rate=0.1, n_estimators=300, max_depth=5)
xgb.fit(X_train, y_train)

# Dự đoán trên tập train và validation
y_pred_train = xgb.predict(X_train)
y_pred_val = xgb.predict(X_val)

# In kết quả
print("Kết quả trên tập train:")
print(classification_report(y_train, y_pred_train))

print("Kết quả trên tập validation:")
print(classification_report(y_val, y_pred_val))

# Đánh giá trên tập test nếu mô hình không bị overfitting
y_pred_test = xgb.predict(X_test)
print("Kết quả trên tập test:")
print(classification_report(y_test, y_pred_test))
# Out:
# Kết quả trên tập train:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3587
#            1       1.00      1.00      1.00       661
#
#     accuracy                           1.00      4248
#    macro avg       1.00      1.00      1.00      4248
# weighted avg       1.00      1.00      1.00      4248
#
# Kết quả trên tập validation:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1176
#            1       0.94      0.84      0.89       240
#
#     accuracy                           0.96      1416
#    macro avg       0.95      0.92      0.93      1416
# weighted avg       0.96      0.96      0.96      1416
#
# Kết quả trên tập test:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1205
#            1       0.94      0.84      0.89       212
#
#     accuracy                           0.97      1417
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
# Khởi tạo KFold với 5 folds và shuffle dữ liệu trước khi chia
kf = KFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(model_xgb, x, y, cv=kf, scoring='recall')
print("Cross-validation scores:", scores)
print("Mean recall:", scores.mean())
print("Standard deviation:", scores.std())
# Out:
# Cross-validation scores: [0.86320755 0.8959276  0.87330317 0.8649789  0.9009009 ]
# Mean recall: 0.8796636240510136
# Standard deviation: 0.015763488250485673

# %%
# Lấy ra tầm quan trọng của từng biến
feature_importances = model_xgb.feature_importances_

# Tạo DataFrame từ tầm quan trọng của biến và tên biến
feature_importance_df = pd.DataFrame({
    'feature': x.columns,
    'importance': feature_importances
})

# Sắp xếp DataFrame theo tầm quan trọng giảm dần
feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)

# Lấy ra 5 biến quan trọng nhất
top_5_features = feature_importance_df.head(5)

# In ra 5 biến quan trọng nhất
print(top_5_features)

# Vẽ biểu đồ thể hiện tầm quan trọng của 5 biến quan trọng nhất
plt.figure(figsize=(10, 6))
plt.bar(top_5_features['feature'], top_5_features['importance'])
plt.xlabel('Biến')
plt.ylabel('Tầm quan trọng')
plt.title('5 biến quan trọng nhất ảnh hưởng đến việc khách hàng rời bỏ dịch vụ')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
#                      feature  importance
# 12            Total_Trans_Ct    0.212050
# 8        Total_Revolving_Bal    0.188335
# 4   Total_Relationship_Count    0.096184
# 11           Total_Trans_Amt    0.069413
# 13       Total_Ct_Chng_Q4_Q1    0.044112
